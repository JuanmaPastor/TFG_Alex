# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from scipy.stats import norm

# %%
#SUCIO
df = pd.read_excel("10Saliva.xlsx")
df.set_index("Muestras", inplace=True)
media = df.mean()
log_media=np.log(media)

med=media.values.tolist()

X_scaled = preprocessing.scale(log_media)


# Density Plot and Histogram of all arrival delays
#sns.distplot(X_scaled, hist=True, kde=True,  bins = int(180/5), color = 'darkblue', 
#             hist_kws={'edgecolor':'black'},
#             kde_kws={'linewidth': 4})

sns.distplot(X_scaled, kde=True, hist = True)
#sns.distplot(X_scaled, norm_hist=True)

# %%
def plotting(x):
    df = pd.read_excel(x)
    df.set_index("Muestras", inplace=True)
    media = df.mean()
    log_media=np.log(media)
    med=media.values.tolist()

    X_scaled = preprocessing.scale(log_media)
    sns.distplot(X_scaled, kde=True, hist = True, fit = norm)
    
    plt.title('Distribución de las medias relativas de las bacterias')
    plt.xlabel('Log de la media estandarizado')
    plt.ylabel('Densidad')

# %%
plotting("118ALLL.xlsx")
print("\nResultados de todos los datos")
# Out:
# Resultados de todos los datos

# %%
plotting("20ALLL.xlsx")
print("\nResultados de todos los datos parseados por 20")
# Out:
# Resultados de todos los datos parseados por 20

# %%
plotting("41Saliva.xlsx")
print("\nResultados de los datos de Saliva")
# Out:
# Resultados de los datos de Saliva

# %%
plotting("10Saliva.xlsx")
print("\nResultados de los datos de Saliva parseados por 10")
# Out:
# Resultados de los datos de Saliva parseados por 10

# %%
plotting("59Lung.xlsx")
print("\nResultados de los datos de Pulmón")
# Out:
# Resultados de los datos de Pulmón

# %%
plotting("15Lung.xlsx")
print("\nResultados de los datos de Pulmón parseados por 15")
# Out:
# Resultados de los datos de Pulmón parseados por 15

# %%
plotting("18Faeces.xlsx")
print("\nResultados de los datos de Heces")
# Out:
# Resultados de los datos de Heces

# %%
plotting("10Faeces.xlsx")
print("\nResultados de los datos de Heces parseados por 10")
# Out:
# Resultados de los datos de Heces parseados por 10
